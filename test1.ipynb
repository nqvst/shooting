# %%
## this is just testing a single file and plotting it
## demo1.vaw is a recording of your recording of the click from the rifel.

import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft
import numpy as np
rate, data = wav.read('demo1.wav')
fft_out = fft(data)
timeScale = list(range(0, len(data)))

# %matplotlib inline
plt.plot(timeScale, data) #np.abs(fft_out)
plt.plot(timeScale, fft_out)
plt.show()
# Out:
# /Users/jack/.virtualenvs/shoot/lib/python3.6/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
